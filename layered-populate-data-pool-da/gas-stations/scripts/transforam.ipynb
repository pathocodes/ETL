# %%
# !python transform_gas_stations.py
# Out:
#                   district district_id
#                      Mitte    11001001
#   Friedrichshain-Kreuzberg    11002002
#                     Pankow    11003003
# Charlottenburg-Wilmersdorf    11004004
#                    Spandau    11005005
#        Steglitz-Zehlendorf    11006006
#       Tempelhof-Schöneberg    11007007
#                   Neukölln    11008008
#           Treptow-Köpenick    11009009
#        Marzahn-Hellersdorf    11010010
#                Lichtenberg    11011011
#              Reinickendorf    11012012
# ✅ Saved 1844 rows to:
# - /Users/khizratariq/clone-repository/layered-populate-data-pool-da/gas-stations/sources/gas_stations_transformed.csv
# - /Users/khizratariq/clone-repository/layered-populate-data-pool-da/gas-stations/sources/gas_stations_transformed.geojson
