# %% [markdown]
# # Malls In Berlin

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine, text, Table, Column, Integer, String, MetaData, ForeignKey, Float, BigInteger
import psycopg2
import warnings
import requests
import time
import logging

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Connect to Database

# %%
user_name=''
password=''

# %%
host = 'localhost'
port = '5433'
database = ''
schema=''

#connection to db after you opened tunnel
engine = create_engine(f'postgresql+psycopg2://{user_name}:{password}@{host}:{port}/{database}')

# %% [markdown]
# ## Import CSV

# %%
df = pd.read_csv("../sources/osm_malls_with_boundaries.csv")
df.head()
# Out:
#   osm_type      osm_id             name_left              website  \
# 0     node   360009454         Cladow-Center                  NaN
# 1     node  2782835444             Nordmeile                  NaN
# 2     node  3982921774   Springpfuhl-Passage                  NaN
# 3     node  5024078544      Fennpfuhl-Karree                  NaN
# 4      way    10632546  Hallen am Borsigturm  http://www.hab-2.de
#
#        opening_hours    addr_street addr_housenumber  addr_postcode addr_city  \
# 0                NaN            NaN              NaN            NaN       NaN
# 1  Mo-Sa 07:00-21:00    Oraniendamm             6-10        13469.0    Berlin
# 2                NaN            NaN              NaN            NaN       NaN
# 3               24/7            NaN              NaN            NaN       NaN
# 4  Mo-Sa 10:00-20:00  Am Borsigturm                2        13507.0    Berlin
#
#          lat  ...  gem_left namgem_left namlan_left lan_left index__neigh  \
# 0  52.455157  ...       NaN         NaN         NaN      NaN          NaN
# 1  52.607867  ...       NaN         NaN         NaN      NaN          NaN
# 2  52.526728  ...       NaN         NaN         NaN      NaN          NaN
# 3  52.528781  ...       NaN         NaN         NaN      NaN          NaN
# 4  52.584576  ...       NaN         NaN         NaN      NaN          NaN
#
#    name gem__neigh namgem__neigh  namlan__neigh  lan__neigh
# 0   NaN        NaN           NaN            NaN         NaN
# 1   NaN        NaN           NaN            NaN         NaN
# 2   NaN        NaN           NaN            NaN         NaN
# 3   NaN        NaN           NaN            NaN         NaN
# 4   NaN        NaN           NaN            NaN         NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Exploring the Data

# %%
df.T
# Out:
#                                             0    \
# osm_type                                   node
# osm_id                                360009454
# name_left                         Cladow-Center
# website                                     NaN
# opening_hours                               NaN
# addr_street                                 NaN
# addr_housenumber                            NaN
# addr_postcode                               NaN
# addr_city                                   NaN
# lat                                   52.455157
# lon                                   13.144413
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.1444131 52.4551567)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             1    \
# osm_type                                   node
# osm_id                               2782835444
# name_left                             Nordmeile
# website                                     NaN
# opening_hours                 Mo-Sa 07:00-21:00
# addr_street                         Oraniendamm
# addr_housenumber                           6-10
# addr_postcode                           13469.0
# addr_city                                Berlin
# lat                                   52.607867
# lon                                   13.325992
# wheelchair                                  NaN
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.3259918 52.6078674)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             2    \
# osm_type                                   node
# osm_id                               3982921774
# name_left                   Springpfuhl-Passage
# website                                     NaN
# opening_hours                               NaN
# addr_street                                 NaN
# addr_housenumber                            NaN
# addr_postcode                               NaN
# addr_city                                   NaN
# lat                                   52.526728
# lon                                   13.540104
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.5401045 52.5267284)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             3    \
# osm_type                                   node
# osm_id                               5024078544
# name_left                      Fennpfuhl-Karree
# website                                     NaN
# opening_hours                              24/7
# addr_street                                 NaN
# addr_housenumber                            NaN
# addr_postcode                               NaN
# addr_city                                   NaN
# lat                                   52.528781
# lon                                   13.471797
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.4717971 52.5287807)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             4    \
# osm_type                                    way
# osm_id                                 10632546
# name_left                  Hallen am Borsigturm
# website                     http://www.hab-2.de
# opening_hours                 Mo-Sa 10:00-20:00
# addr_street                       Am Borsigturm
# addr_housenumber                              2
# addr_postcode                           13507.0
# addr_city                                Berlin
# lat                                   52.584576
# lon                                   13.285772
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.2857717 52.5845756)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             5    \
# osm_type                                    way
# osm_id                                 11076700
# name_left            Einkaufszentrum »Der Clou«
# website           https://www.derclouberlin.de/
# opening_hours                 Mo-Sa 10:00-20:00
# addr_street                   Scharnweberstraße
# addr_housenumber                            140
# addr_postcode                           13405.0
# addr_city                                Berlin
# lat                                   52.563039
# lon                                   13.328485
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.3284849 52.5630387)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                                 6    \
# osm_type                                        way
# osm_id                                     11249452
# name_left                             Linden Center
# website           https://m.linden-center-berlin.de
# opening_hours                     Mo-Sa 09:30-20:00
# addr_street                          Prerower Platz
# addr_housenumber                                  1
# addr_postcode                               13051.0
# addr_city                                    Berlin
# lat                                       52.564378
# lon                                        13.50604
# wheelchair                                      yes
# operator                                        NaN
# brand                                           NaN
# start_date                                      NaN
# level                                           NaN
# source                                 OSM Overpass
# geometry              POINT (13.5060401 52.5643776)
# index__district                                 NaN
# name__district                                  NaN
# gem_left                                        NaN
# namgem_left                                     NaN
# namlan_left                                     NaN
# lan_left                                        NaN
# index__neigh                                    NaN
# name                                            NaN
# gem__neigh                                      NaN
# namgem__neigh                                   NaN
# namlan__neigh                                   NaN
# lan__neigh                                      NaN
#
#                                            7                              8    \
# osm_type                                   way                            way
# osm_id                                11249566                       18771934
# name_left                  Allee-Center Berlin            Bahnhof Lichtenberg
# website                                    NaN                            NaN
# opening_hours                Mo-Sa 07:00-20:00                    06:00-22:00
# addr_street                  Landsberger Allee                 Weitlingstraße
# addr_housenumber                           277                             22
# addr_postcode                          13055.0                        10317.0
# addr_city                               Berlin                         Berlin
# lat                                  52.535248                      52.509421
# lon                                  13.496467                      13.496944
# wheelchair                                 yes                            yes
# operator                                   NaN                            NaN
# brand                                      NaN                            NaN
# start_date                                 NaN                            NaN
# level                                      NaN                            NaN
# source                            OSM Overpass                   OSM Overpass
# geometry          POINT (13.4964673 52.535248)  POINT (13.4969436 52.5094209)
# index__district                            NaN                            NaN
# name__district                             NaN                            NaN
# gem_left                                   NaN                            NaN
# namgem_left                                NaN                            NaN
# namlan_left                                NaN                            NaN
# lan_left                                   NaN                            NaN
# index__neigh                               NaN                            NaN
# name                                       NaN                            NaN
# gem__neigh                                 NaN                            NaN
# namgem__neigh                              NaN                            NaN
# namlan__neigh                              NaN                            NaN
# lan__neigh                                 NaN                            NaN
#
#                                                    9    ...  \
# osm_type                                           way  ...
# osm_id                                        20980117  ...
# name_left                         Gesundbrunnen-Center  ...
# website           https://www.gesundbrunnen-center.de/  ...
# opening_hours                        Mo-Sa 08:00-21:00  ...
# addr_street                                  Badstraße  ...
# addr_housenumber                                     4  ...
# addr_postcode                                  13357.0  ...
# addr_city                                       Berlin  ...
# lat                                          52.549773  ...
# lon                                           13.38953  ...
# wheelchair                                         yes  ...
# operator                                           NaN  ...
# brand                                              NaN  ...
# start_date                                         NaN  ...
# level                                              NaN  ...
# source                                    OSM Overpass  ...
# geometry                  POINT (13.3895302 52.549773)  ...
# index__district                                    NaN  ...
# name__district                                     NaN  ...
# gem_left                                           NaN  ...
# namgem_left                                        NaN  ...
# namlan_left                                        NaN  ...
# lan_left                                           NaN  ...
# index__neigh                                       NaN  ...
# name                                               NaN  ...
# gem__neigh                                         NaN  ...
# namgem__neigh                                      NaN  ...
# namlan__neigh                                      NaN  ...
# lan__neigh                                         NaN  ...
#
#                                             94                            95   \
# osm_type                                    way                           way
# osm_id                               1065811824                    1238152790
# name_left                 Ring-Center Berlin II             Tempelhofer Hafen
# website                                     NaN                           NaN
# opening_hours         Mo-Sa 10:00-20:00; PH off             Mo-Sa 10:00-20:00
# addr_street                   Frankfurter Allee                           NaN
# addr_housenumber                        113-117                           NaN
# addr_postcode                           10365.0                           NaN
# addr_city                                Berlin                           NaN
# lat                                   52.514327                     52.455806
# lon                                   13.476502                     13.386016
# wheelchair                                  yes                           yes
# operator                                    NaN                           NaN
# brand                                       NaN                           NaN
# start_date                                  NaN                    2009-04-29
# level                                       NaN                           NaN
# source                             OSM Overpass                  OSM Overpass
# geometry          POINT (13.4765019 52.5143274)  POINT (13.386016 52.4558061)
# index__district                             NaN                           NaN
# name__district                              NaN                           NaN
# gem_left                                    NaN                           NaN
# namgem_left                                 NaN                           NaN
# namlan_left                                 NaN                           NaN
# lan_left                                    NaN                           NaN
# index__neigh                                NaN                           NaN
# name                                        NaN                           NaN
# gem__neigh                                  NaN                           NaN
# namgem__neigh                               NaN                           NaN
# namlan__neigh                               NaN                           NaN
# lan__neigh                                  NaN                           NaN
#
#                                                   96   \
# osm_type                                          way
# osm_id                                     1244901436
# name_left                          Märkisches Zentrum
# website           https://www.maerkisches-zentrum.de/
# opening_hours                                     NaN
# addr_street                        Senftenberger Ring
# addr_housenumber                                   3a
# addr_postcode                                 13439.0
# addr_city                                      Berlin
# lat                                         52.597613
# lon                                         13.354518
# wheelchair                                        yes
# operator              MV Geschäftshaus-Marketing GmbH
# brand                                             NaN
# start_date                                        NaN
# level                                             NaN
# source                                   OSM Overpass
# geometry                POINT (13.3545182 52.5976128)
# index__district                                   NaN
# name__district                                    NaN
# gem_left                                          NaN
# namgem_left                                       NaN
# namlan_left                                       NaN
# lan_left                                          NaN
# index__neigh                                      NaN
# name                                              NaN
# gem__neigh                                        NaN
# namgem__neigh                                     NaN
# namlan__neigh                                     NaN
# lan__neigh                                        NaN
#
#                                            97                            98   \
# osm_type                              relation                      relation
# osm_id                                  380240                       2671992
# name_left                                The Q                           NaN
# website                                    NaN                           NaN
# opening_hours                Mo-Sa 08:00-22:00                           NaN
# addr_street                    Friedrichstraße                           NaN
# addr_housenumber                            67                           NaN
# addr_postcode                          10117.0                           NaN
# addr_city                               Berlin                           NaN
# lat                                  52.512614                     52.522378
# lon                                  13.390499                     13.465988
# wheelchair                                 yes                           yes
# operator                                   NaN                           NaN
# brand                                      NaN                           NaN
# start_date                                 NaN                           NaN
# level                                      NaN                           NaN
# source                            OSM Overpass                  OSM Overpass
# geometry          POINT (13.390499 52.5126135)  POINT (13.465988 52.5223779)
# index__district                            NaN                           NaN
# name__district                             NaN                           NaN
# gem_left                                   NaN                           NaN
# namgem_left                                NaN                           NaN
# namlan_left                                NaN                           NaN
# lan_left                                   NaN                           NaN
# index__neigh                               NaN                           NaN
# name                                       NaN                           NaN
# gem__neigh                                 NaN                           NaN
# namgem__neigh                              NaN                           NaN
# namlan__neigh                              NaN                           NaN
# lan__neigh                                 NaN                           NaN
#
#                                             99   \
# osm_type                               relation
# osm_id                                  4540346
# name_left                         Neumann-Forum
# website                                     NaN
# opening_hours                 Mo-Sa 07:00-21:00
# addr_street                                 NaN
# addr_housenumber                            NaN
# addr_postcode                               NaN
# addr_city                                   NaN
# lat                                   52.561378
# lon                                   13.422762
# wheelchair                                  NaN
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.4227619 52.5613783)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                                100  \
# osm_type                                  relation
# osm_id                                     7701165
# name_left                         Gropius Passagen
# website           https://www.gropius-passagen.de/
# opening_hours                    Mo-Sa 10:00-20:00
# addr_street                                    NaN
# addr_housenumber                               NaN
# addr_postcode                                  NaN
# addr_city                                      NaN
# lat                                      52.430128
# lon                                      13.455199
# wheelchair                                     yes
# operator                 Unibail-Rodamco-Westfield
# brand                                    Westfield
# start_date                                     NaN
# level                                          NaN
# source                                OSM Overpass
# geometry             POINT (13.4551989 52.4301282)
# index__district                                NaN
# name__district                                 NaN
# gem_left                                       NaN
# namgem_left                                    NaN
# namlan_left                                    NaN
# lan_left                                       NaN
# index__neigh                                   NaN
# name                                           NaN
# gem__neigh                                     NaN
# namgem__neigh                                  NaN
# namlan__neigh                                  NaN
# lan__neigh                                     NaN
#
#                                             101  \
# osm_type                               relation
# osm_id                                  8504555
# name_left               Forum Landsberger Allee
# website                                     NaN
# opening_hours                               NaN
# addr_street                                 NaN
# addr_housenumber                            NaN
# addr_postcode                               NaN
# addr_city                                   NaN
# lat                                    52.52926
# lon                                    13.45634
# wheelchair                                  yes
# operator                                    NaN
# brand                                       NaN
# start_date                                  NaN
# level                                       NaN
# source                             OSM Overpass
# geometry          POINT (13.4563404 52.5292601)
# index__district                             NaN
# name__district                              NaN
# gem_left                                    NaN
# namgem_left                                 NaN
# namlan_left                                 NaN
# lan_left                                    NaN
# index__neigh                                NaN
# name                                        NaN
# gem__neigh                                  NaN
# namgem__neigh                               NaN
# namlan__neigh                               NaN
# lan__neigh                                  NaN
#
#                                             102                            103
# osm_type                               relation                       relation
# osm_id                                 17353905                       19445153
# name_left                  GEHAG Einkaufzentrum               Dolgensee-Center
# website                                     NaN                            NaN
# opening_hours                               NaN                            NaN
# addr_street                                 NaN                            NaN
# addr_housenumber                            NaN                            NaN
# addr_postcode                               NaN                            NaN
# addr_city                                   NaN                            NaN
# lat                                   52.437559                      52.493574
# lon                                   13.446334                      13.507232
# wheelchair                                  NaN                            NaN
# operator                                    NaN                            NaN
# brand                                       NaN                            NaN
# start_date                                  NaN                            NaN
# level                                       NaN                            NaN
# source                             OSM Overpass                   OSM Overpass
# geometry          POINT (13.4463336 52.4375589)  POINT (13.5072316 52.4935737)
# index__district                             NaN                            NaN
# name__district                              NaN                            NaN
# gem_left                                    NaN                            NaN
# namgem_left                                 NaN                            NaN
# namlan_left                                 NaN                            NaN
# lan_left                                    NaN                            NaN
# index__neigh                                NaN                            NaN
# name                                        NaN                            NaN
# gem__neigh                                  NaN                            NaN
# namgem__neigh                               NaN                            NaN
# namlan__neigh                               NaN                            NaN
# lan__neigh                                  NaN                            NaN
#
# [30 rows x 104 columns]

# %%
df = df.drop_duplicates()

# %%
df.isna().sum()
# Out:
# osm_type              0
# osm_id                0
# name_left             4
# website              76
# opening_hours        41
# addr_street          41
# addr_housenumber     42
# addr_postcode        41
# addr_city            45
# lat                   0
# lon                   0
# wheelchair           23
# operator             98
# brand               103
# start_date           96
# level               104
# source                0
# geometry              0
# index__district     104
# name__district      104
# gem_left            104
# namgem_left         104
# namlan_left         104
# lan_left            104
# index__neigh        104
# name                104
# gem__neigh          104
# namgem__neigh       104
# namlan__neigh       104
# lan__neigh          104
# dtype: int64

# %%
df_columns_drop = df.copy()
columns_to_drop = [
    'osm_type',
    'operator', 
    'brand',
    'start_date', 
    'level', 
    'gem_left',
    'namgem_left',
    'namlan_left',
    'lan_left',
    'index__neigh',
    'name',
    'gem__neigh',
    'namgem__neigh',
    'namlan__neigh',
    'lan__neigh'
]  
df_kept = df_columns_drop.drop(columns=columns_to_drop)
df_kept.head()
# Out:
#        osm_id             name_left              website      opening_hours  \
# 0   360009454         Cladow-Center                  NaN                NaN
# 1  2782835444             Nordmeile                  NaN  Mo-Sa 07:00-21:00
# 2  3982921774   Springpfuhl-Passage                  NaN                NaN
# 3  5024078544      Fennpfuhl-Karree                  NaN               24/7
# 4    10632546  Hallen am Borsigturm  http://www.hab-2.de  Mo-Sa 10:00-20:00
#
#      addr_street addr_housenumber  addr_postcode addr_city        lat  \
# 0            NaN              NaN            NaN       NaN  52.455157
# 1    Oraniendamm             6-10        13469.0    Berlin  52.607867
# 2            NaN              NaN            NaN       NaN  52.526728
# 3            NaN              NaN            NaN       NaN  52.528781
# 4  Am Borsigturm                2        13507.0    Berlin  52.584576
#
#          lon wheelchair        source                       geometry  \
# 0  13.144413        yes  OSM Overpass  POINT (13.1444131 52.4551567)
# 1  13.325992        NaN  OSM Overpass  POINT (13.3259918 52.6078674)
# 2  13.540104        yes  OSM Overpass  POINT (13.5401045 52.5267284)
# 3  13.471797        yes  OSM Overpass  POINT (13.4717971 52.5287807)
# 4  13.285772        yes  OSM Overpass  POINT (13.2857717 52.5845756)
#
#    index__district  name__district
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN

# %%
df_kept.dtypes
# Out:
# osm_id                int64
# name_left            object
# website              object
# opening_hours        object
# addr_street          object
# addr_housenumber     object
# addr_postcode       float64
# addr_city            object
# lat                 float64
# lon                 float64
# wheelchair           object
# source               object
# geometry             object
# index__district     float64
# name__district      float64
# dtype: object

# %%
df_kept.isna().sum()
# Out:
# osm_id                0
# name_left             4
# website              76
# opening_hours        41
# addr_street          41
# addr_housenumber     42
# addr_postcode        41
# addr_city            45
# lat                   0
# lon                   0
# wheelchair           23
# source                0
# geometry              0
# index__district     104
# name__district      104
# dtype: int64

# %% [markdown]
# ### Dealing with Null Values

# %%
df_kept = df_kept.fillna({
    'name_left': 'None',
    'website': 'None',
    'opening_hours': 'None',
    'addr_street': 'None',
    'addr_housenumber': '',
    'addr_postcode': '',
    'addr_city': '',
    'wheelchair': 'None',
    'index__district': '',
    'name__district': ''
})

# %%
df_kept.isna().sum()
# Out:
# osm_id              0
# name_left           0
# website             0
# opening_hours       0
# addr_street         0
# addr_housenumber    0
# addr_postcode       0
# addr_city           0
# lat                 0
# lon                 0
# wheelchair          0
# source              0
# geometry            0
# index__district     0
# name__district      0
# dtype: int64

# %%
df_kept
# Out:
#          osm_id                name_left                           website  \
# 0     360009454            Cladow-Center                              None
# 1    2782835444                Nordmeile                              None
# 2    3982921774      Springpfuhl-Passage                              None
# 3    5024078544         Fennpfuhl-Karree                              None
# 4      10632546     Hallen am Borsigturm               http://www.hab-2.de
# ..          ...                      ...                               ...
# 99      4540346            Neumann-Forum                              None
# 100     7701165         Gropius Passagen  https://www.gropius-passagen.de/
# 101     8504555  Forum Landsberger Allee                              None
# 102    17353905     GEHAG Einkaufzentrum                              None
# 103    19445153         Dolgensee-Center                              None
#
#          opening_hours    addr_street addr_housenumber addr_postcode  \
# 0                 None           None
# 1    Mo-Sa 07:00-21:00    Oraniendamm             6-10       13469.0
# 2                 None           None
# 3                 24/7           None
# 4    Mo-Sa 10:00-20:00  Am Borsigturm                2       13507.0
# ..                 ...            ...              ...           ...
# 99   Mo-Sa 07:00-21:00           None
# 100  Mo-Sa 10:00-20:00           None
# 101               None           None
# 102               None           None
# 103               None           None
#
#     addr_city        lat        lon wheelchair        source  \
# 0              52.455157  13.144413        yes  OSM Overpass
# 1      Berlin  52.607867  13.325992       None  OSM Overpass
# 2              52.526728  13.540104        yes  OSM Overpass
# 3              52.528781  13.471797        yes  OSM Overpass
# 4      Berlin  52.584576  13.285772        yes  OSM Overpass
# ..        ...        ...        ...        ...           ...
# 99             52.561378  13.422762       None  OSM Overpass
# 100            52.430128  13.455199        yes  OSM Overpass
# 101            52.529260  13.456340        yes  OSM Overpass
# 102            52.437559  13.446334       None  OSM Overpass
# 103            52.493574  13.507232       None  OSM Overpass
#
#                           geometry index__district name__district
# 0    POINT (13.1444131 52.4551567)
# 1    POINT (13.3259918 52.6078674)
# 2    POINT (13.5401045 52.5267284)
# 3    POINT (13.4717971 52.5287807)
# 4    POINT (13.2857717 52.5845756)
# ..                             ...             ...            ...
# 99   POINT (13.4227619 52.5613783)
# 100  POINT (13.4551989 52.4301282)
# 101  POINT (13.4563404 52.5292601)
# 102  POINT (13.4463336 52.4375589)
# 103  POINT (13.5072316 52.4935737)
#
# [104 rows x 15 columns]

# %% [markdown]
# ### Rename Columns

# %%
df_kept = df_kept.rename(columns={
    'osm_id': 'id',
    'name_left': 'name',
    'addr_street': 'street',
    'addr_housenumber': 'housenumber',
    'addr_postcode': 'postcode',
    'addr_city': 'city',
    'lat': 'latitude',
    'lon': 'longitude',
    'index__district': 'district_id',
    'name__district': 'district'   
})

# %%
for col in df_kept.select_dtypes(include='object').columns:
    df_kept[col] = df_kept[col].astype(str).str.strip().str.title()

# %%
df_kept.T
# Out:
#                                          0                              1    \
# id                                 360009454                     2782835444
# name                           Cladow-Center                      Nordmeile
# website                                 None                           None
# opening_hours                           None              Mo-Sa 07:00-21:00
# street                                  None                    Oraniendamm
# housenumber                                                            6-10
# postcode                                                            13469.0
# city                                                                 Berlin
# latitude                           52.455157                      52.607867
# longitude                          13.144413                      13.325992
# wheelchair                               Yes                           None
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.1444131 52.4551567)  Point (13.3259918 52.6078674)
# district_id
# district
#
#                                          2                              3    \
# id                                3982921774                     5024078544
# name                     Springpfuhl-Passage               Fennpfuhl-Karree
# website                                 None                           None
# opening_hours                           None                           24/7
# street                                  None                           None
# housenumber
# postcode
# city
# latitude                           52.526728                      52.528781
# longitude                          13.540104                      13.471797
# wheelchair                               Yes                            Yes
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.5401045 52.5267284)  Point (13.4717971 52.5287807)
# district_id
# district
#
#                                          4                              5    \
# id                                  10632546                       11076700
# name                    Hallen Am Borsigturm     Einkaufszentrum »Der Clou«
# website                  Http://Www.Hab-2.De  Https://Www.Derclouberlin.De/
# opening_hours              Mo-Sa 10:00-20:00              Mo-Sa 10:00-20:00
# street                         Am Borsigturm              Scharnweberstraße
# housenumber                                2                            140
# postcode                             13507.0                        13405.0
# city                                  Berlin                         Berlin
# latitude                           52.584576                      52.563039
# longitude                          13.285772                      13.328485
# wheelchair                               Yes                            Yes
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.2857717 52.5845756)  Point (13.3284849 52.5630387)
# district_id
# district
#
#                                              6    \
# id                                      11249452
# name                               Linden Center
# website        Https://M.Linden-Center-Berlin.De
# opening_hours                  Mo-Sa 09:30-20:00
# street                            Prerower Platz
# housenumber                                    1
# postcode                                 13051.0
# city                                      Berlin
# latitude                               52.564378
# longitude                               13.50604
# wheelchair                                   Yes
# source                              Osm Overpass
# geometry           Point (13.5060401 52.5643776)
# district_id
# district
#
#                                         7                              8    \
# id                                 11249566                       18771934
# name                    Allee-Center Berlin            Bahnhof Lichtenberg
# website                                None                           None
# opening_hours             Mo-Sa 07:00-20:00                    06:00-22:00
# street                    Landsberger Allee                 Weitlingstraße
# housenumber                             277                             22
# postcode                            13055.0                        10317.0
# city                                 Berlin                         Berlin
# latitude                          52.535248                      52.509421
# longitude                         13.496467                      13.496944
# wheelchair                              Yes                            Yes
# source                         Osm Overpass                   Osm Overpass
# geometry       Point (13.4964673 52.535248)  Point (13.4969436 52.5094209)
# district_id
# district
#
#                                                 9    ...  \
# id                                         20980117  ...
# name                           Gesundbrunnen-Center  ...
# website        Https://Www.Gesundbrunnen-Center.De/  ...
# opening_hours                     Mo-Sa 08:00-21:00  ...
# street                                    Badstraße  ...
# housenumber                                       4  ...
# postcode                                    13357.0  ...
# city                                         Berlin  ...
# latitude                                  52.549773  ...
# longitude                                  13.38953  ...
# wheelchair                                      Yes  ...
# source                                 Osm Overpass  ...
# geometry               Point (13.3895302 52.549773)  ...
# district_id                                          ...
# district                                             ...
#
#                                          94                            95   \
# id                                1065811824                    1238152790
# name                   Ring-Center Berlin Ii             Tempelhofer Hafen
# website                                 None                          None
# opening_hours      Mo-Sa 10:00-20:00; Ph Off             Mo-Sa 10:00-20:00
# street                     Frankfurter Allee                          None
# housenumber                          113-117
# postcode                             10365.0
# city                                  Berlin
# latitude                           52.514327                     52.455806
# longitude                          13.476502                     13.386016
# wheelchair                               Yes                           Yes
# source                          Osm Overpass                  Osm Overpass
# geometry       Point (13.4765019 52.5143274)  Point (13.386016 52.4558061)
# district_id
# district
#
#                                                96   \
# id                                      1244901436
# name                            Märkisches Zentrum
# website        Https://Www.Maerkisches-Zentrum.De/
# opening_hours                                 None
# street                          Senftenberger Ring
# housenumber                                     3A
# postcode                                   13439.0
# city                                        Berlin
# latitude                                 52.597613
# longitude                                13.354518
# wheelchair                                     Yes
# source                                Osm Overpass
# geometry             Point (13.3545182 52.5976128)
# district_id
# district
#
#                                         97                            98   \
# id                                   380240                       2671992
# name                                  The Q                          None
# website                                None                          None
# opening_hours             Mo-Sa 08:00-22:00                          None
# street                      Friedrichstraße                          None
# housenumber                              67
# postcode                            10117.0
# city                                 Berlin
# latitude                          52.512614                     52.522378
# longitude                         13.390499                     13.465988
# wheelchair                              Yes                           Yes
# source                         Osm Overpass                  Osm Overpass
# geometry       Point (13.390499 52.5126135)  Point (13.465988 52.5223779)
# district_id
# district
#
#                                          99   \
# id                                   4540346
# name                           Neumann-Forum
# website                                 None
# opening_hours              Mo-Sa 07:00-21:00
# street                                  None
# housenumber
# postcode
# city
# latitude                           52.561378
# longitude                          13.422762
# wheelchair                              None
# source                          Osm Overpass
# geometry       Point (13.4227619 52.5613783)
# district_id
# district
#
#                                             100  \
# id                                      7701165
# name                           Gropius Passagen
# website        Https://Www.Gropius-Passagen.De/
# opening_hours                 Mo-Sa 10:00-20:00
# street                                     None
# housenumber
# postcode
# city
# latitude                              52.430128
# longitude                             13.455199
# wheelchair                                  Yes
# source                             Osm Overpass
# geometry          Point (13.4551989 52.4301282)
# district_id
# district
#
#                                          101                            102  \
# id                                   8504555                       17353905
# name                 Forum Landsberger Allee           Gehag Einkaufzentrum
# website                                 None                           None
# opening_hours                           None                           None
# street                                  None                           None
# housenumber
# postcode
# city
# latitude                            52.52926                      52.437559
# longitude                           13.45634                      13.446334
# wheelchair                               Yes                           None
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.4563404 52.5292601)  Point (13.4463336 52.4375589)
# district_id
# district
#
#                                          103
# id                                  19445153
# name                        Dolgensee-Center
# website                                 None
# opening_hours                           None
# street                                  None
# housenumber
# postcode
# city
# latitude                           52.493574
# longitude                          13.507232
# wheelchair                              None
# source                          Osm Overpass
# geometry       Point (13.5072316 52.4935737)
# district_id
# district
#
# [15 rows x 104 columns]

# %%
df_kept.dtypes
# Out:
# id                 int64
# name              object
# website           object
# opening_hours     object
# street            object
# housenumber       object
# postcode          object
# city              object
# latitude         float64
# longitude        float64
# wheelchair        object
# source            object
# geometry          object
# district_id       object
# district          object
# dtype: object

# %% [markdown]
# ### Changing Datatypes

# %%
df_kept['postcode'] = pd.to_numeric(df_kept['postcode'], errors='coerce').astype('Int64')

# %%
df_kept.dtypes
# Out:
# id                 int64
# name              object
# website           object
# opening_hours     object
# street            object
# housenumber       object
# postcode           Int64
# city              object
# latitude         float64
# longitude        float64
# wheelchair        object
# source            object
# geometry          object
# district_id       object
# district          object
# dtype: object

# %%
df_kept['postcode'] = df_kept['postcode'].fillna(0).astype('int64')

# %% [markdown]
# ### Checking Datatypes for 'city' column

# %%
df_kept.value_counts('city')
# Out:
# city
# Berlin    59
#           45
# Name: count, dtype: int64

# %%
in_berlin = (
    (df_kept['latitude'] >= 52.3383) & (df_kept['latitude'] <= 52.6755) &
    (df_kept['longitude'] >= 13.0884) & (df_kept['longitude'] <= 13.7612)
)
print(f"All coordinates in Berlin: {in_berlin.all()}")
print(f"Rows outside Berlin: {df_kept[~in_berlin]}")
# Out:
# All coordinates in Berlin: True
# Rows outside Berlin: Empty DataFrame
# Columns: [id, name, website, opening_hours, street, housenumber, postcode, city, latitude, longitude, wheelchair, source, geometry, district_id, district]
# Index: []

# %%
df_kept['city'] = df_kept['city'].replace('', 'Berlin')

# %%
df_kept['housenumber'] = df_kept['housenumber'].replace('', 'None')

# %% [markdown]
# ## Find district, district_id

# %%
df_kept.T
# Out:
#                                          0                              1    \
# id                                 360009454                     2782835444
# name                           Cladow-Center                      Nordmeile
# website                                 None                           None
# opening_hours                           None              Mo-Sa 07:00-21:00
# street                                  None                    Oraniendamm
# housenumber                             None                           6-10
# postcode                                   0                          13469
# city                                  Berlin                         Berlin
# latitude                           52.455157                      52.607867
# longitude                          13.144413                      13.325992
# wheelchair                               Yes                           None
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.1444131 52.4551567)  Point (13.3259918 52.6078674)
# district_id
# district
#
#                                          2                              3    \
# id                                3982921774                     5024078544
# name                     Springpfuhl-Passage               Fennpfuhl-Karree
# website                                 None                           None
# opening_hours                           None                           24/7
# street                                  None                           None
# housenumber                             None                           None
# postcode                                   0                              0
# city                                  Berlin                         Berlin
# latitude                           52.526728                      52.528781
# longitude                          13.540104                      13.471797
# wheelchair                               Yes                            Yes
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.5401045 52.5267284)  Point (13.4717971 52.5287807)
# district_id
# district
#
#                                          4                              5    \
# id                                  10632546                       11076700
# name                    Hallen Am Borsigturm     Einkaufszentrum »Der Clou«
# website                  Http://Www.Hab-2.De  Https://Www.Derclouberlin.De/
# opening_hours              Mo-Sa 10:00-20:00              Mo-Sa 10:00-20:00
# street                         Am Borsigturm              Scharnweberstraße
# housenumber                                2                            140
# postcode                               13507                          13405
# city                                  Berlin                         Berlin
# latitude                           52.584576                      52.563039
# longitude                          13.285772                      13.328485
# wheelchair                               Yes                            Yes
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.2857717 52.5845756)  Point (13.3284849 52.5630387)
# district_id
# district
#
#                                              6    \
# id                                      11249452
# name                               Linden Center
# website        Https://M.Linden-Center-Berlin.De
# opening_hours                  Mo-Sa 09:30-20:00
# street                            Prerower Platz
# housenumber                                    1
# postcode                                   13051
# city                                      Berlin
# latitude                               52.564378
# longitude                               13.50604
# wheelchair                                   Yes
# source                              Osm Overpass
# geometry           Point (13.5060401 52.5643776)
# district_id
# district
#
#                                         7                              8    \
# id                                 11249566                       18771934
# name                    Allee-Center Berlin            Bahnhof Lichtenberg
# website                                None                           None
# opening_hours             Mo-Sa 07:00-20:00                    06:00-22:00
# street                    Landsberger Allee                 Weitlingstraße
# housenumber                             277                             22
# postcode                              13055                          10317
# city                                 Berlin                         Berlin
# latitude                          52.535248                      52.509421
# longitude                         13.496467                      13.496944
# wheelchair                              Yes                            Yes
# source                         Osm Overpass                   Osm Overpass
# geometry       Point (13.4964673 52.535248)  Point (13.4969436 52.5094209)
# district_id
# district
#
#                                                 9    ...  \
# id                                         20980117  ...
# name                           Gesundbrunnen-Center  ...
# website        Https://Www.Gesundbrunnen-Center.De/  ...
# opening_hours                     Mo-Sa 08:00-21:00  ...
# street                                    Badstraße  ...
# housenumber                                       4  ...
# postcode                                      13357  ...
# city                                         Berlin  ...
# latitude                                  52.549773  ...
# longitude                                  13.38953  ...
# wheelchair                                      Yes  ...
# source                                 Osm Overpass  ...
# geometry               Point (13.3895302 52.549773)  ...
# district_id                                          ...
# district                                             ...
#
#                                          94                            95   \
# id                                1065811824                    1238152790
# name                   Ring-Center Berlin Ii             Tempelhofer Hafen
# website                                 None                          None
# opening_hours      Mo-Sa 10:00-20:00; Ph Off             Mo-Sa 10:00-20:00
# street                     Frankfurter Allee                          None
# housenumber                          113-117                          None
# postcode                               10365                             0
# city                                  Berlin                        Berlin
# latitude                           52.514327                     52.455806
# longitude                          13.476502                     13.386016
# wheelchair                               Yes                           Yes
# source                          Osm Overpass                  Osm Overpass
# geometry       Point (13.4765019 52.5143274)  Point (13.386016 52.4558061)
# district_id
# district
#
#                                                96   \
# id                                      1244901436
# name                            Märkisches Zentrum
# website        Https://Www.Maerkisches-Zentrum.De/
# opening_hours                                 None
# street                          Senftenberger Ring
# housenumber                                     3A
# postcode                                     13439
# city                                        Berlin
# latitude                                 52.597613
# longitude                                13.354518
# wheelchair                                     Yes
# source                                Osm Overpass
# geometry             Point (13.3545182 52.5976128)
# district_id
# district
#
#                                         97                            98   \
# id                                   380240                       2671992
# name                                  The Q                          None
# website                                None                          None
# opening_hours             Mo-Sa 08:00-22:00                          None
# street                      Friedrichstraße                          None
# housenumber                              67                          None
# postcode                              10117                             0
# city                                 Berlin                        Berlin
# latitude                          52.512614                     52.522378
# longitude                         13.390499                     13.465988
# wheelchair                              Yes                           Yes
# source                         Osm Overpass                  Osm Overpass
# geometry       Point (13.390499 52.5126135)  Point (13.465988 52.5223779)
# district_id
# district
#
#                                          99   \
# id                                   4540346
# name                           Neumann-Forum
# website                                 None
# opening_hours              Mo-Sa 07:00-21:00
# street                                  None
# housenumber                             None
# postcode                                   0
# city                                  Berlin
# latitude                           52.561378
# longitude                          13.422762
# wheelchair                              None
# source                          Osm Overpass
# geometry       Point (13.4227619 52.5613783)
# district_id
# district
#
#                                             100  \
# id                                      7701165
# name                           Gropius Passagen
# website        Https://Www.Gropius-Passagen.De/
# opening_hours                 Mo-Sa 10:00-20:00
# street                                     None
# housenumber                                None
# postcode                                      0
# city                                     Berlin
# latitude                              52.430128
# longitude                             13.455199
# wheelchair                                  Yes
# source                             Osm Overpass
# geometry          Point (13.4551989 52.4301282)
# district_id
# district
#
#                                          101                            102  \
# id                                   8504555                       17353905
# name                 Forum Landsberger Allee           Gehag Einkaufzentrum
# website                                 None                           None
# opening_hours                           None                           None
# street                                  None                           None
# housenumber                             None                           None
# postcode                                   0                              0
# city                                  Berlin                         Berlin
# latitude                            52.52926                      52.437559
# longitude                           13.45634                      13.446334
# wheelchair                               Yes                           None
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.4563404 52.5292601)  Point (13.4463336 52.4375589)
# district_id
# district
#
#                                          103
# id                                  19445153
# name                        Dolgensee-Center
# website                                 None
# opening_hours                           None
# street                                  None
# housenumber                             None
# postcode                                   0
# city                                  Berlin
# latitude                           52.493574
# longitude                          13.507232
# wheelchair                              None
# source                          Osm Overpass
# geometry       Point (13.5072316 52.4935737)
# district_id
# district
#
# [15 rows x 104 columns]

# %%
df_kept.drop(columns=['district_id', 'district'], errors='ignore', inplace=True)

# %%
desired_order = [
    "id", "name", "website", "opening_hours", "street", "housenumber",
    "postcode", "city", "latitude", "longitude", "wheelchair", "source", "geometry"
]
df_kept = df_kept[desired_order]

# %%
df_kept.T
# Out:
#                                          0                              1    \
# id                                 360009454                     2782835444
# name                           Cladow-Center                      Nordmeile
# website                                 None                           None
# opening_hours                           None              Mo-Sa 07:00-21:00
# street                                  None                    Oraniendamm
# housenumber                             None                           6-10
# postcode                                   0                          13469
# city                                  Berlin                         Berlin
# latitude                           52.455157                      52.607867
# longitude                          13.144413                      13.325992
# wheelchair                               Yes                           None
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.1444131 52.4551567)  Point (13.3259918 52.6078674)
#
#                                          2                              3    \
# id                                3982921774                     5024078544
# name                     Springpfuhl-Passage               Fennpfuhl-Karree
# website                                 None                           None
# opening_hours                           None                           24/7
# street                                  None                           None
# housenumber                             None                           None
# postcode                                   0                              0
# city                                  Berlin                         Berlin
# latitude                           52.526728                      52.528781
# longitude                          13.540104                      13.471797
# wheelchair                               Yes                            Yes
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.5401045 52.5267284)  Point (13.4717971 52.5287807)
#
#                                          4                              5    \
# id                                  10632546                       11076700
# name                    Hallen Am Borsigturm     Einkaufszentrum »Der Clou«
# website                  Http://Www.Hab-2.De  Https://Www.Derclouberlin.De/
# opening_hours              Mo-Sa 10:00-20:00              Mo-Sa 10:00-20:00
# street                         Am Borsigturm              Scharnweberstraße
# housenumber                                2                            140
# postcode                               13507                          13405
# city                                  Berlin                         Berlin
# latitude                           52.584576                      52.563039
# longitude                          13.285772                      13.328485
# wheelchair                               Yes                            Yes
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.2857717 52.5845756)  Point (13.3284849 52.5630387)
#
#                                              6    \
# id                                      11249452
# name                               Linden Center
# website        Https://M.Linden-Center-Berlin.De
# opening_hours                  Mo-Sa 09:30-20:00
# street                            Prerower Platz
# housenumber                                    1
# postcode                                   13051
# city                                      Berlin
# latitude                               52.564378
# longitude                               13.50604
# wheelchair                                   Yes
# source                              Osm Overpass
# geometry           Point (13.5060401 52.5643776)
#
#                                         7                              8    \
# id                                 11249566                       18771934
# name                    Allee-Center Berlin            Bahnhof Lichtenberg
# website                                None                           None
# opening_hours             Mo-Sa 07:00-20:00                    06:00-22:00
# street                    Landsberger Allee                 Weitlingstraße
# housenumber                             277                             22
# postcode                              13055                          10317
# city                                 Berlin                         Berlin
# latitude                          52.535248                      52.509421
# longitude                         13.496467                      13.496944
# wheelchair                              Yes                            Yes
# source                         Osm Overpass                   Osm Overpass
# geometry       Point (13.4964673 52.535248)  Point (13.4969436 52.5094209)
#
#                                                 9    ...  \
# id                                         20980117  ...
# name                           Gesundbrunnen-Center  ...
# website        Https://Www.Gesundbrunnen-Center.De/  ...
# opening_hours                     Mo-Sa 08:00-21:00  ...
# street                                    Badstraße  ...
# housenumber                                       4  ...
# postcode                                      13357  ...
# city                                         Berlin  ...
# latitude                                  52.549773  ...
# longitude                                  13.38953  ...
# wheelchair                                      Yes  ...
# source                                 Osm Overpass  ...
# geometry               Point (13.3895302 52.549773)  ...
#
#                                          94                            95   \
# id                                1065811824                    1238152790
# name                   Ring-Center Berlin Ii             Tempelhofer Hafen
# website                                 None                          None
# opening_hours      Mo-Sa 10:00-20:00; Ph Off             Mo-Sa 10:00-20:00
# street                     Frankfurter Allee                          None
# housenumber                          113-117                          None
# postcode                               10365                             0
# city                                  Berlin                        Berlin
# latitude                           52.514327                     52.455806
# longitude                          13.476502                     13.386016
# wheelchair                               Yes                           Yes
# source                          Osm Overpass                  Osm Overpass
# geometry       Point (13.4765019 52.5143274)  Point (13.386016 52.4558061)
#
#                                                96   \
# id                                      1244901436
# name                            Märkisches Zentrum
# website        Https://Www.Maerkisches-Zentrum.De/
# opening_hours                                 None
# street                          Senftenberger Ring
# housenumber                                     3A
# postcode                                     13439
# city                                        Berlin
# latitude                                 52.597613
# longitude                                13.354518
# wheelchair                                     Yes
# source                                Osm Overpass
# geometry             Point (13.3545182 52.5976128)
#
#                                         97                            98   \
# id                                   380240                       2671992
# name                                  The Q                          None
# website                                None                          None
# opening_hours             Mo-Sa 08:00-22:00                          None
# street                      Friedrichstraße                          None
# housenumber                              67                          None
# postcode                              10117                             0
# city                                 Berlin                        Berlin
# latitude                          52.512614                     52.522378
# longitude                         13.390499                     13.465988
# wheelchair                              Yes                           Yes
# source                         Osm Overpass                  Osm Overpass
# geometry       Point (13.390499 52.5126135)  Point (13.465988 52.5223779)
#
#                                          99   \
# id                                   4540346
# name                           Neumann-Forum
# website                                 None
# opening_hours              Mo-Sa 07:00-21:00
# street                                  None
# housenumber                             None
# postcode                                   0
# city                                  Berlin
# latitude                           52.561378
# longitude                          13.422762
# wheelchair                              None
# source                          Osm Overpass
# geometry       Point (13.4227619 52.5613783)
#
#                                             100  \
# id                                      7701165
# name                           Gropius Passagen
# website        Https://Www.Gropius-Passagen.De/
# opening_hours                 Mo-Sa 10:00-20:00
# street                                     None
# housenumber                                None
# postcode                                      0
# city                                     Berlin
# latitude                              52.430128
# longitude                             13.455199
# wheelchair                                  Yes
# source                             Osm Overpass
# geometry          Point (13.4551989 52.4301282)
#
#                                          101                            102  \
# id                                   8504555                       17353905
# name                 Forum Landsberger Allee           Gehag Einkaufzentrum
# website                                 None                           None
# opening_hours                           None                           None
# street                                  None                           None
# housenumber                             None                           None
# postcode                                   0                              0
# city                                  Berlin                         Berlin
# latitude                            52.52926                      52.437559
# longitude                           13.45634                      13.446334
# wheelchair                               Yes                           None
# source                          Osm Overpass                   Osm Overpass
# geometry       Point (13.4563404 52.5292601)  Point (13.4463336 52.4375589)
#
#                                          103
# id                                  19445153
# name                        Dolgensee-Center
# website                                 None
# opening_hours                           None
# street                                  None
# housenumber                             None
# postcode                                   0
# city                                  Berlin
# latitude                           52.493574
# longitude                          13.507232
# wheelchair                              None
# source                          Osm Overpass
# geometry       Point (13.5072316 52.4935737)
#
# [13 rows x 104 columns]

# %%
# neighborhoods = gpd.read_file("lor_ortsteile.geojson").to_crs("EPSG:4326")

geojson_path = "../sources/wfs_downloads/lor_ortsteile.geojson"
neighborhoods = gpd.read_file(geojson_path).to_crs("EPSG:4326")

neighborhoods = neighborhoods.rename(columns={
    "BEZIRK": "district",
    "OTEIL": "neighborhood",
    "spatial_name": "neighborhood_id"
})

neighborhoods.head()
# Out:
#              gml_id neighborhood_id spatial_alias spatial_type  neighborhood  \
# 0  re_ortsteil.0101            0101         Mitte      Polygon         Mitte
# 1  re_ortsteil.0102            0102        Moabit      Polygon        Moabit
# 2  re_ortsteil.0103            0103  Hansaviertel      Polygon  Hansaviertel
# 3  re_ortsteil.0104            0104    Tiergarten      Polygon    Tiergarten
# 4  re_ortsteil.0105            0105       Wedding      Polygon       Wedding
#
#   district  FLAECHE_HA                                           geometry
# 0    Mitte   1063.8748  POLYGON ((13.41649 52.52696, 13.41635 52.52702...
# 1    Mitte    768.7909  POLYGON ((13.33884 52.51974, 13.33884 52.51974...
# 2    Mitte     52.5337  POLYGON ((13.34322 52.51557, 13.34323 52.51557...
# 3    Mitte    516.0672  POLYGON ((13.36879 52.49878, 13.36891 52.49877...
# 4    Mitte    919.9112  POLYGON ((13.34656 52.53879, 13.34664 52.53878...

# %%
# If you have latitude and longitude columns:
df_clean = df_kept.copy()
df_clean['geometry'] = df_clean.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)
df_clean = gpd.GeoDataFrame(df_clean, geometry='geometry', crs='EPSG:4326')

# %%
df_with_districts = gpd.sjoin(
    df_clean, 
    neighborhoods[["district", "neighborhood", "neighborhood_id", "geometry"]],
    how="left",
    predicate="within"
)

df_final = df_with_districts.drop(columns=["geometry", "index_right"])

# %%
df_final.head()
# Out:
#            id                  name              website      opening_hours  \
# 0   360009454         Cladow-Center                 None               None
# 1  2782835444             Nordmeile                 None  Mo-Sa 07:00-21:00
# 2  3982921774   Springpfuhl-Passage                 None               None
# 3  5024078544      Fennpfuhl-Karree                 None               24/7
# 4    10632546  Hallen Am Borsigturm  Http://Www.Hab-2.De  Mo-Sa 10:00-20:00
#
#           street housenumber  postcode    city   latitude  longitude  \
# 0           None        None         0  Berlin  52.455157  13.144413
# 1    Oraniendamm        6-10     13469  Berlin  52.607867  13.325992
# 2           None        None         0  Berlin  52.526728  13.540104
# 3           None        None         0  Berlin  52.528781  13.471797
# 4  Am Borsigturm           2     13507  Berlin  52.584576  13.285772
#
#   wheelchair        source             district   neighborhood neighborhood_id
# 0        Yes  Osm Overpass              Spandau         Kladow            0506
# 1       None  Osm Overpass        Reinickendorf  Waidmannslust            1207
# 2        Yes  Osm Overpass  Marzahn-Hellersdorf        Marzahn            1001
# 3        Yes  Osm Overpass          Lichtenberg      Fennpfuhl            1111
# 4        Yes  Osm Overpass        Reinickendorf          Tegel            1202

# %%
# https://www.regionalstatistik.de

district_mapping = {
    'Mitte': '11001001',
    'Friedrichshain-Kreuzberg': '11002002',
    'Pankow': '11003003',
    'Charlottenburg-Wilmersdorf': '11004004',
    'Spandau': '11005005',
    'Steglitz-Zehlendorf': '11006006',
    'Tempelhof-Schöneberg': '11007007',
    'Neukölln': '11008008',
    'Treptow-Köpenick': '11009009',
    'Marzahn-Hellersdorf': '11010010',
    'Lichtenberg': '11011011',
    'Reinickendorf': '11012012'
}

df_final['district_id'] = df_final['district'].map(district_mapping).astype(str)

unmapped = df_final[~df_final['district'].isin(district_mapping.keys())]['district'].unique()
if len(unmapped) > 0:
    print("⚠️ Unmapped districts found:", unmapped)

df_final.head()
# Out:
#            id                  name              website      opening_hours  \
# 0   360009454         Cladow-Center                 None               None
# 1  2782835444             Nordmeile                 None  Mo-Sa 07:00-21:00
# 2  3982921774   Springpfuhl-Passage                 None               None
# 3  5024078544      Fennpfuhl-Karree                 None               24/7
# 4    10632546  Hallen Am Borsigturm  Http://Www.Hab-2.De  Mo-Sa 10:00-20:00
#
#           street housenumber  postcode    city   latitude  longitude  \
# 0           None        None         0  Berlin  52.455157  13.144413
# 1    Oraniendamm        6-10     13469  Berlin  52.607867  13.325992
# 2           None        None         0  Berlin  52.526728  13.540104
# 3           None        None         0  Berlin  52.528781  13.471797
# 4  Am Borsigturm           2     13507  Berlin  52.584576  13.285772
#
#   wheelchair        source             district   neighborhood  \
# 0        Yes  Osm Overpass              Spandau         Kladow
# 1       None  Osm Overpass        Reinickendorf  Waidmannslust
# 2        Yes  Osm Overpass  Marzahn-Hellersdorf        Marzahn
# 3        Yes  Osm Overpass          Lichtenberg      Fennpfuhl
# 4        Yes  Osm Overpass        Reinickendorf          Tegel
#
#   neighborhood_id district_id
# 0            0506    11005005
# 1            1207    11012012
# 2            1001    11010010
# 3            1111    11011011
# 4            1202    11012012

# %%
df_final.head().T
# Out:
#                              0                  1                    2  \
# id                   360009454         2782835444           3982921774
# name             Cladow-Center          Nordmeile  Springpfuhl-Passage
# website                   None               None                 None
# opening_hours             None  Mo-Sa 07:00-21:00                 None
# street                    None        Oraniendamm                 None
# housenumber               None               6-10                 None
# postcode                     0              13469                    0
# city                    Berlin             Berlin               Berlin
# latitude             52.455157          52.607867            52.526728
# longitude            13.144413          13.325992            13.540104
# wheelchair                 Yes               None                  Yes
# source            Osm Overpass       Osm Overpass         Osm Overpass
# district               Spandau      Reinickendorf  Marzahn-Hellersdorf
# neighborhood            Kladow      Waidmannslust              Marzahn
# neighborhood_id           0506               1207                 1001
# district_id           11005005           11012012             11010010
#
#                                 3                     4
# id                     5024078544              10632546
# name             Fennpfuhl-Karree  Hallen Am Borsigturm
# website                      None   Http://Www.Hab-2.De
# opening_hours                24/7     Mo-Sa 10:00-20:00
# street                       None         Am Borsigturm
# housenumber                  None                     2
# postcode                        0                 13507
# city                       Berlin                Berlin
# latitude                52.528781             52.584576
# longitude               13.471797             13.285772
# wheelchair                    Yes                   Yes
# source               Osm Overpass          Osm Overpass
# district              Lichtenberg         Reinickendorf
# neighborhood            Fennpfuhl                 Tegel
# neighborhood_id              1111                  1202
# district_id              11011011              11012012

# %%
df_final.isna().sum()
# Out:
# id                 0
# name               0
# website            0
# opening_hours      0
# street             0
# housenumber        0
# postcode           0
# city               0
# latitude           0
# longitude          0
# wheelchair         0
# source             0
# district           0
# neighborhood       0
# neighborhood_id    0
# district_id        0
# dtype: int64

# %%
df_final['neighborhood_id'] = pd.to_numeric(df_final['neighborhood_id'], errors='coerce').astype('Int64')

# %%
df_final.dtypes
# Out:
# id                   int64
# name                object
# website             object
# opening_hours       object
# street              object
# housenumber         object
# postcode             int64
# city                object
# latitude           float64
# longitude          float64
# wheelchair          object
# source              object
# district            object
# neighborhood        object
# neighborhood_id      Int64
# district_id         object
# dtype: object

# %%
df_final.head().T
# Out:
#                              0                  1                    2  \
# id                   360009454         2782835444           3982921774
# name             Cladow-Center          Nordmeile  Springpfuhl-Passage
# website                   None               None                 None
# opening_hours             None  Mo-Sa 07:00-21:00                 None
# street                    None        Oraniendamm                 None
# housenumber               None               6-10                 None
# postcode                     0              13469                    0
# city                    Berlin             Berlin               Berlin
# latitude             52.455157          52.607867            52.526728
# longitude            13.144413          13.325992            13.540104
# wheelchair                 Yes               None                  Yes
# source            Osm Overpass       Osm Overpass         Osm Overpass
# district               Spandau      Reinickendorf  Marzahn-Hellersdorf
# neighborhood            Kladow      Waidmannslust              Marzahn
# neighborhood_id            506               1207                 1001
# district_id           11005005           11012012             11010010
#
#                                 3                     4
# id                     5024078544              10632546
# name             Fennpfuhl-Karree  Hallen Am Borsigturm
# website                      None   Http://Www.Hab-2.De
# opening_hours                24/7     Mo-Sa 10:00-20:00
# street                       None         Am Borsigturm
# housenumber                  None                     2
# postcode                        0                 13507
# city                       Berlin                Berlin
# latitude                52.528781             52.584576
# longitude               13.471797             13.285772
# wheelchair                    Yes                   Yes
# source               Osm Overpass          Osm Overpass
# district              Lichtenberg         Reinickendorf
# neighborhood            Fennpfuhl                 Tegel
# neighborhood_id              1111                  1202
# district_id              11011011              11012012

# %% [markdown]
# ## Map of malls in Berlin

# %%
fig, ax = plt.subplots(figsize=(10, 10))
neighborhoods.plot(ax=ax, facecolor='none', edgecolor='blue', linewidth=1, alpha=0.5, label='District Polygons')
df_clean.plot(ax=ax, color='red', markersize=20, label='Mall Points')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Mall Points and Berlin District Polygons')
plt.legend()
plt.show()

# %%
engine.dispose()

# %% [markdown]
# ## Create the Table

# %%
create_table_query = """
CREATE TABLE IF NOT EXISTS berlin_source_data.malls (
    id BIGINT PRIMARY KEY,
    name VARCHAR(255),
    website VARCHAR(255),
    opening_hours VARCHAR(255),
    street VARCHAR(255),
    housenumber VARCHAR(255),
    postcode INTEGER,
    city VARCHAR(255),
    latitude FLOAT,
    longitude FLOAT,
    wheelchair VARCHAR(255),
    source VARCHAR(255),
    district VARCHAR(255),
    neighborhood VARCHAR(255),
    neighborhood_id INTEGER,
    district_id VARCHAR(10),
    CONSTRAINT district_id_fk FOREIGN KEY (district_id)
        REFERENCES berlin_source_data.districts(district_id)
        ON DELETE RESTRICT
        ON UPDATE CASCADE
);
"""

with engine.connect() as connection:
    connection.execute(text(create_table_query))
    connection.commit()

# %% [markdown]
# ## Populate Table to Database

# %%
df_final.to_sql(
    f'malls',        # table name
    engine,
    schema=schema,
    if_exists='append', 
    index=False
)

print("DataFrame sent to PostgreSQL using .to_sql() with psycopg2!")
# Out:
# DataFrame sent to PostgreSQL using .to_sql() with psycopg2!
